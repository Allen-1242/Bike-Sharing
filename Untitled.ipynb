# %%
import pandas as pd
df1= pd.read_csv("dec.csv")
df1.head()
# Out:
#                                                                                                 dec
# DY  MAX  MIN  AVG  DEP  HDD  CDD   WTR   SNW  DPTH  SPD  SPD  DIR  MIN  PSBL  S-S  WX     SPD    DR
# 1   57   42   50   6    15   0    0      0    0     8.1  20   330    M     M  2    1      23    320
# 2   53   36   45   1    20   0    0      0    0     3    10   50     M     M  5           11     50
# 3   57   38   48   5    17   0    0.03   0    0     4.3  15   340    M     M  5    1      20    300
# 4   56   36   46   3    19   0    0      0    0     4.6  15   160    M     M  6    8      17    160

# %%
df1.dtypes
# Out:
# dec    object
# dtype: object

# %%
df1['dec']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dec'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-59427420a434> in <module>()
# ----> 1 df1['dec']
#
# ...
